# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import numpy as np

import MDAnalysis as mda
from MDAnalysis.lib.mdamath import triclinic_vectors

# %%
sys.path.insert(0, "../")

import mdtools
from mdtools.lib.distances import *

# Custom scripts
from mdtools.system.chemistry import *
from mdtools.system.species import *
from mdtools.system.system import *

# %% [markdown]
# # Testing

# %%
amon = MonomerType(1, size = 1.0, charge = -1.0)
bmon = MonomerType(2, size = 1.0, charge = 2.0)

diblock = Diblock(1, amon, bmon, 20, 10)

box = Box([10, 10, 10])
sys = MolecularSystem(box)
sys.add_species(diblock, nmol = 5)
sys.generate_molecules()

# %%
sys.draw()
