# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

import MDAnalysis as mda
from MDAnalysis.lib.mdamath import triclinic_vectors

# %%
sys.path.insert(0, "../")

import mdtools
from mdtools.lib.distances import *

# Custom scripts
from mdtools.system.chemistry import *
from mdtools.system.species import *
from mdtools.system.system import *

from mdtools.tools.builders import build_multi_polyion

# %% [markdown]
# # Testing

# %%
za = -1.0
zc = 1.0
dpa = 50
dpc = 50

na = 10
nc = 10
ns = 0

counter = True

sys = build_multi_polyion(na, nc, ns, dpa, dpc, za, zc, 20, counter = False)

# %%
sys.draw()

# %% [markdown]
# # Builders

# %%
from mdtools.tools.builders import *

# %%
build_multi_polyion(10, 10, 0, 100, 100, -1.0, 1.0, 100, counter = True)
